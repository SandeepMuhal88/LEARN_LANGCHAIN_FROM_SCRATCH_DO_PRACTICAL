# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader('Cleaned Ml Roadmap.pdf')

docs = loader.load()

splitter = CharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=0,
    separator=''
)

result = splitter.split_documents(docs)

print(result[1].page_content)
# Out:
# DL), and Artificial Intelligence (AI). This
# comprehensive guide is designed to provide a structured learning path, from foundational
# concepts in Python and mathematics to advanced topics in deep lea

# %%
# %pip install langchain-google-genai --upgrade

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import PyPDFLoader

# %%
# 1. Load PDF
loader = PyPDFLoader('Cleaned Ml Roadmap.pdf')
docs = loader.load()

print(f"Loaded pages: {len(docs)}")
# Out:
# Loaded pages: 4

# %%
# 2. Improved text splitter (recursive = smarter chunking)
splitter = RecursiveCharacterTextSplitter(
    chunk_size=700,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""]
)

chunks = splitter.split_documents(docs)

print(f"Total chunks created: {len(chunks)}")
# Out:
# Total chunks created: 10

# %%
# Embeddings (Gemini)
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key="YOUR_API_KEY"
)

# %%
# vector_store = FAISS.from_documents(chunks, embeddings)
# vector_store.save_local("faiss_store_dl")
