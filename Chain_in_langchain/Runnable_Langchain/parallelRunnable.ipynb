# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.runnables import RunnableSequence,RunnableParallel
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate


load_dotenv()
# Out:
# True

# %%
model= ChatGoogleGenerativeAI(
    model='gemini-2.5-flash-lite'
)

# %%
prompt1 = PromptTemplate(
    template='Generate a tweet about {topic}',
    input_variables=['topic']
)

prompt2 = PromptTemplate(
    template='Generate a Linkedin post about {topic}',
    input_variables=['topic']
)

# %%
parser=StrOutputParser()

# %%
parallel_chain=RunnableParallel({
    'tweet':RunnableSequence(prompt1, model, parser),
    'linkedin':RunnableSequence(prompt2, model, parser)
})

result=parallel_chain.invoke({'topic':'AI'})
print(result['tweet'])
print(result['linkedin'])
# Out:
# Here are a few options for a tweet about AI, choose the one that best fits your vibe:
#
# **Option 1 (Enthusiastic & Forward-Looking):**
#
# > The pace of AI innovation is truly mind-blowing! 🤯 From groundbreaking research to real-world applications, we're witnessing a revolution that's reshaping our future. What's the most exciting AI development you've seen lately? #AI #ArtificialIntelligence #FutureTech
#
# **Option 2 (Curious & Thought-Provoking):**
#
# > AI is no longer science fiction; it's a powerful tool we're integrating into our lives. But with great power comes great responsibility. What are your biggest hopes and concerns about the rise of AI? 🤔 #AIethics #TechTrends #Innovation
#
# **Option 3 (Simple & Direct):**
#
# > Fascinated by the continuous evolution of Artificial Intelligence. It's incredible to see how AI is enhancing creativity, solving complex problems, and driving efficiency. The possibilities are endless! #AI #MachineLearning #Tech
#
# **Option 4 (Slightly Humorous):**
#
# > My toaster is starting to ask me about my day. Pretty sure it's an AI upgrade I didn't sign up for... 😂 But seriously, the advancements in AI are incredible! #AI #RobotUprising (kidding... mostly) #Tech
#
# **Option 5 (Focus on a Specific Aspect):**
#
# > From personalized recommendations to medical breakthroughs, AI is quietly transforming industries. Excited to see how it continues to empower us and unlock new potential. #AIforGood #DigitalTransformation #Innovation
#
# **Remember to consider:**
#
# *   **Your audience:** Who are you trying to reach?
# *   **Your message:** What specific point do you want to convey?
# *   **Visuals:** Consider adding an AI-related image or GIF to make your tweet more engaging!
#
# Let me know if you'd like more options or want to tweak one of these!
# Here are a few options for a LinkedIn post about AI, ranging in tone and focus. Choose the one that best suits your style and audience!
#
# ---
#
# **Option 1: Enthusiastic & Forward-Looking**
#
# **Headline:** The AI Revolution is Here, and It's Reshaping Our World 🚀
#
# **Body:**
# We're living through an extraordinary time where Artificial Intelligence is no longer a concept of the future, but a tangible force driving innovation across every industry. From revolutionizing customer experiences to unlocking scientific breakthroughs, AI's potential is vast and its impact is accelerating.
#
# As professionals, understanding and embracing AI isn't just an advantage – it's becoming a necessity. What are your thoughts on the most impactful AI applications you've seen recently? I'm eager to hear your perspectives!
#
# #AI #ArtificialIntelligence #Innovation #FutureOfWork #Technology #DigitalTransformation
#
# ---
#
# **Option 2: Thought-Provoking & Balanced**
#
# **Headline:** Navigating the AI Landscape: Opportunities and Considerations
#
# **Body:**
# Artificial Intelligence presents incredible opportunities for efficiency, creativity, and problem-solving. We're seeing its power in everything from predictive analytics to personalized learning.
#
# However, as we harness this transformative technology, it's crucial to also consider the ethical implications, the need for responsible development, and the ongoing evolution of the workforce. How are you preparing your teams and organizations for the AI-driven future? Let's discuss.
#
# #AI #ArtificialIntelligence #Ethics #Responsibility #FutureOfWork #TechTrends #Leadership
#
# ---
#
# **Option 3: Practical & Action-Oriented**
#
# **Headline:** Beyond the Hype: Practical Ways AI is Driving Business Value Today
#
# **Body:**
# While the conversations around AI can sometimes feel abstract, its real-world applications are already delivering tangible business value. Think about:
#
# *   **Automating repetitive tasks:** Freeing up human capital for more strategic work.
# *   **Enhancing data analysis:** Uncovering insights that lead to better decision-making.
# *   **Personalizing customer journeys:** Driving engagement and loyalty.
#
# What are some practical AI tools or strategies that have made a significant difference in your work or industry? Share your experiences below!
#
# #AI #BusinessIntelligence #Productivity #Efficiency #DataAnalytics #CustomerExperience #AIinBusiness
#
# ---
#
# **Option 4: Personal Reflection & Learning**
#
# **Headline:** My Journey into the World of AI 💡
#
# **Body:**
# Lately, I've been deeply fascinated by the rapid advancements in Artificial Intelligence. It's a field that constantly challenges my understanding and opens up new avenues for thought. Whether it's generative AI for creative tasks or AI-powered tools for [mention a specific area you're interested in, e.g., marketing, coding, research], the possibilities seem endless.
#
# I'm committed to continuous learning in this space. What resources (articles, courses, podcasts) have you found most valuable for understanding AI? Looking forward to learning from your recommendations!
#
# #AI #LearningAndDevelopment #ContinuousLearning #Technology #ArtificialIntelligence #ProfessionalGrowth
#
# ---
#
# **Remember to:**
#
# *   **Add a relevant image or video** to make your post more engaging. This could be a graphic related to AI, a short video explaining a concept, or even a professional headshot.
# *   **Tag relevant people or companies** if appropriate.
# *   **Engage with comments** you receive on your post.
#
# Choose the option that resonates most with you and adapt it to your specific context! Good luck!
