# %%
# %pip install duckduckgo-search

# %%
# %pip install langchain_experimental

# %%
# %pip install -U langchain langchain-core langchain-community duckduckgo-search

# %%
from langchain_community.vectorstores import Chroma

# %%
# %pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.9.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.1.8 in d:\project-to-learn\.langchain\lib\site-packages (from ddgs) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in d:\project-to-learn\.langchain\lib\site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=4.9.4 in d:\project-to-learn\.langchain\lib\site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in d:\project-to-learn\.langchain\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in d:\project-to-learn\.langchain\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.0)
# Requirement already satisfied: certifi in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\project-to-learn\.langchain\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing_extensions>=4.5 in d:\project-to-learn\.langchain\lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.9.2-py3-none-any.whl (41 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Installing collected packages: brotli, socksio, hyperframe, hpack, fake-useragent, h2, ddgs
#
#    ----- ---------------------------------- 1/7 [socksio]
#    ----------------- ---------------------- 3/7 [hpack]
#    ---------------------- ----------------- 4/7 [fake-useragent]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------------- 7/7 [ddgs]
#
# Successfully installed brotli-1.2.0 ddgs-9.9.2 fake-useragent-2.2.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 socksio-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')

print(results)
# Out:
# November 2, 2025 - India Today is a weekly Indian English-language news magazine published by Living Media India Limited. It is the most widely circulated magazine in India, with a readership of close to 8 million..In 2014, India Today launched a new online ... Check out the latest news from India and around the world. Latest India news on Bollywood, Politics, Business, Cricket, Technology and Travel. Today 's news : Get latest and Breaking News on Politics, Business, Lifestyle, Entertainment and Sports along with News updates from around the world. Top News . Air India warns of possible delays after check-in system glitch at airports. A new Top 40: Ranking rich Indians who are making others wealthy. Conventional rich lists rank people by the wealth they amassed for themselves. But the true measure of wealth creation might be in what an entrepreneur or a multi-generation family has created for others. AajTak: Hindi news (हिंदी समाचार) website, watch live tv coverages, Latest Khabar, Breaking news in Hindi of India , World, Sports, business, film and Entertainment. India Today . Live: New pinnacle in Ayodhya, says Yogi Adityanath ahead of PM’s flag hoisting. He thought it was lung cancer.
