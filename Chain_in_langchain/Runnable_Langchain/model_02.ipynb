# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(
    model='gemini-2.0-flash'
)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
Explain {topic} in 5 point.
""")

# %%
prompt=PromptTemplate(
    template='make a report about {Topic}',
    input_variables=['Topic']
)

# %%
parser = StrOutputParser()

# %%
chain=prompt | model | parser

# %%
print(chain.invoke({"Topic": "black hole"}))
# Out:
# ## Black Holes: Cosmic Vacuum Cleaners & Gravitational Enigmas
#
# **Introduction:**
#
# Black holes are among the most fascinating and mysterious objects in the universe. Defined by their immense gravitational pull, they are regions of spacetime where gravity is so strong that nothing, not even light, can escape. This report will delve into the formation, properties, detection, and ongoing research surrounding these cosmic giants.
#
# **Formation of Black Holes:**
#
# Black holes are primarily formed through two main mechanisms:
#
# *   **Stellar Collapse:** The most common type, stellar black holes, form when massive stars (typically more than 20 times the mass of the Sun) reach the end of their lives. After exhausting their nuclear fuel, they collapse under their own gravity. If the core is massive enough, it will collapse into a singularity, a point of infinite density, surrounded by an event horizon.
#
# *   **Primordial Black Holes:**  A theoretical type of black hole hypothesized to have formed in the very early universe due to density fluctuations. These could range in size from microscopic to incredibly massive.  Evidence for their existence remains elusive.
#
# **Types of Black Holes:**
#
# Black holes are categorized based on their mass:
#
# *   **Stellar Black Holes:**  Formed from the collapse of massive stars, typically ranging from a few to tens of solar masses.  These are the most commonly observed type.
#
# *   **Intermediate-Mass Black Holes (IMBHs):**  A rarer type, with masses ranging from hundreds to thousands of solar masses.  Their formation mechanisms are still debated, but may involve the merging of stellar black holes or runaway stellar collisions in dense star clusters.
#
# *   **Supermassive Black Holes (SMBHs):**  Found at the centers of most, if not all, galaxies.  These behemoths range from millions to billions of solar masses.  The exact formation mechanisms are still under investigation, but they likely involve the accretion of vast amounts of gas and dust over billions of years, possibly fueled by galactic mergers.
#
# **Key Properties of Black Holes:**
#
# *   **Event Horizon:** The boundary beyond which nothing can escape. It's defined by the black hole's mass and represents the "point of no return." The radius of the event horizon is known as the Schwarzschild radius.
#
# *   **Singularity:**  The theoretical point at the center of a black hole where all of its mass is concentrated into an infinitely small space, resulting in infinite density.  The laws of physics as we know them break down at the singularity.
#
# *   **Accretion Disk:** A swirling disk of gas, dust, and other matter that orbits a black hole. As matter spirals inward, it heats up due to friction, emitting intense radiation across the electromagnetic spectrum, making black holes detectable.
#
# *   **Ergosphere:** For rotating (Kerr) black holes, the ergosphere is a region outside the event horizon where spacetime is dragged around by the black hole's rotation.  Objects within the ergosphere can theoretically extract energy from the black hole.
#
# **Detecting Black Holes:**
#
# Since black holes do not emit light, they are indirectly detected through their gravitational effects on surrounding matter:
#
# *   **Gravitational Lensing:**  The bending of light around a massive object, like a black hole, can distort the images of background objects.
#
# *   **X-ray Emissions:**  As matter falls into an accretion disk, it heats up to millions of degrees and emits powerful X-rays.  These X-rays are a key signature of black hole activity.
#
# *   **Stellar Orbits:**  Observing the unusual orbits of stars around an invisible, massive object can indicate the presence of a black hole.  This technique was used to confirm the existence of the supermassive black hole Sagittarius A* at the center of our Milky Way galaxy.
#
# *   **Gravitational Waves:**  The Laser Interferometer Gravitational-Wave Observatory (LIGO) and Virgo detectors have directly detected gravitational waves produced by the merging of black holes, providing strong evidence for their existence and properties.
#
# **Impact of Black Holes on their Environment:**
#
# Black holes play a significant role in shaping the evolution of galaxies:
#
# *   **Active Galactic Nuclei (AGNs):** Supermassive black holes at the centers of galaxies can become active, accreting vast amounts of matter and launching powerful jets of energy and particles into intergalactic space. These AGNs can influence star formation and galaxy evolution.
#
# *   **Tidal Disruption Events (TDEs):** When a star gets too close to a black hole, the black hole's tidal forces can tear the star apart. This results in a bright flare of radiation as the stellar debris is accreted.
#
# *   **Regulation of Star Formation:** The energy released by active black holes can heat up the surrounding gas, inhibiting star formation in some regions of a galaxy.
#
# **Ongoing Research and Future Directions:**
#
# Black hole research is a vibrant field with many open questions:
#
# *   **Understanding SMBH Formation:**  The formation mechanisms of supermassive black holes remain a major puzzle.
#
# *   **Probing the Singularity:** Scientists are working to develop a theory of quantum gravity that can describe the physics at the singularity.
#
# *   **Black Hole Information Paradox:**  This paradox arises from the apparent loss of information when matter falls into a black hole, which contradicts the laws of quantum mechanics.  Researchers are exploring potential resolutions, such as the "firewall" hypothesis.
#
# *   **Event Horizon Telescope (EHT):**  The EHT is a global network of telescopes that aims to image the event horizon of black holes directly. The first image of a black hole, M87*, was captured by the EHT in 2019, marking a major milestone in black hole research.
#
# *   **Next-Generation Gravitational Wave Detectors:** Future gravitational wave detectors, such as the Einstein Telescope and Cosmic Explorer, will be more sensitive and capable of detecting gravitational waves from a wider range of black hole mergers, providing new insights into black hole populations and their evolution.
#
# **Conclusion:**
#
# Black holes are extreme objects that challenge our understanding of gravity and the universe. Their immense gravitational pull and bizarre properties continue to fascinate scientists and inspire awe. Ongoing research is pushing the boundaries of our knowledge, promising to reveal even more about these cosmic enigmas and their crucial role in the evolution of galaxies.

# %%
for chunk in chain.stream({"Topic": "Transformers"}):
    print(chunk, end="")
# Out:
# ## Transformers: More Than Meets the Eye - A Comprehensive Overview
#
# Transformers, giant robots in disguise, have captured the imaginations of audiences worldwide for decades. But beyond the popular franchise, the concept of Transformers represents a compelling blend of science fiction, action, and philosophical themes. This report delves into the history, lore, and cultural impact of Transformers, exploring its evolution from toys to a global phenomenon.
#
# **I. Origins and Evolution:**
#
# *   **Takara and Hasbro Partnership (1980s):** The Transformers franchise originated from two separate toy lines: Takara's *Diaclone* and *Micro Change*. Hasbro recognized the potential of these transforming robots and licensed them, creating the unified Transformers brand in 1984.
# *   **The Original Generation (G1):** The initial storyline established the epic conflict between the heroic Autobots, led by Optimus Prime, and the evil Decepticons, commanded by Megatron. The war for Energon, their life force, brought them to Earth, where they continued their struggle.
# *   **Multiple Iterations and Continuities:** Over the years, Transformers has been reimagined and rebooted numerous times, leading to various continuities like *Beast Wars*, *Robots in Disguise*, *Armada*, *Energon*, *Cybertron*, *Animated*, and the *Aligned Continuity* (encompassing games, novels, and cartoons). Each continuity offers a unique take on the core conflict and characters.
# *   **Live-Action Films (2007-Present):** Michael Bay's live-action film series brought Transformers to a new generation, showcasing impressive visual effects and action sequences. While commercially successful, the films have been met with mixed critical reception due to their focus on spectacle over narrative depth.
# *   **Renewed Focus on Storytelling:** Recent iterations, like the *War for Cybertron* trilogy on Netflix and the film *Bumblebee*, have shifted towards more character-driven narratives and a closer adherence to the spirit of the original cartoon.
#
# **II. Key Characters and Factions:**
#
# *   **Autobots:** The "good guys," fighting for freedom and justice. Key members include:
#     *   **Optimus Prime:** The noble and courageous leader of the Autobots, known for his unwavering morality and iconic truck form.
#     *   **Bumblebee:** A loyal and brave scout, often serving as a bridge between the Autobots and humans.
#     *   **Ratchet:** The Autobot medic, responsible for keeping his comrades in working order.
#     *   **Ironhide:** A seasoned warrior and Optimus Prime's bodyguard.
#     *   **Prowl:** The Autobot strategist and tactician.
# *   **Decepticons:** The "bad guys," seeking power and control. Key members include:    *   **Megatron:** The ruthless and tyrannical leader of the Decepticons, constantly seeking to conquer Cybertron and beyond.
#     *   **Starscream:** Megatron's ambitious and treacherous second-in-command, always plotting to usurp his leader.
#     *   **Soundwave:** The Decepticon communications officer, known for his loyalty and emotionless demeanor.
#     *   **Shockwave:** The Decepticon scientist, driven by logic and experimentation.
#     *   **Skywarp and Thundercracker:** The Decepticon Seekers, known for their aerial combat abilities.*   **Other Factions:** Some continuities introduce additional factions with their own agendas, such as the Maximals and Predacons in *Beast Wars*, or the Quintessons, creators of the Transformers.
#
# **III. Core Themes and Concepts:**
#
# *   **Good vs. Evil:** The central conflict between the Autobots and Decepticons explores the timeless battle between good and evil, freedom and tyranny.
# *   **War and Peace:** The franchise grapples with the consequences of war and the potential for peace, highlighting the sacrifices and complexities involved in both.
# *   **Technology and Humanity:** Transformers often explores the relationship between humans and advanced technology, questioning the potential benefits and dangers of technological progress.
# *   **Transformation and Change:** The ability to transform is not only a physical attribute but also a metaphor for personal growth and adaptation.
# *   **Friendship and Loyalty:** The bonds between Autobots and Decepticons, both within and between factions, highlight the importance of friendship and loyalty.
#
# **IV. Cultural Impact:**
#
# *   **Global Phenomenon:** Transformers has become a global phenomenon, inspiring countless toys, comics, cartoons, video games, and films.
# *   **Nostalgia and Fandom:** The franchise holds a special place in the hearts of many who grew up with the original cartoon and toys, fostering a dedicated and passionate fanbase.
# *   **Influence on Popular Culture:** Transformers has influenced other science fiction works, inspiring similar concepts of transforming robots and intergalactic conflicts.
# *   **Commercial Success:** The Transformers franchise has generated billions of dollars in revenue, making it one of the most successful media franchises of all time.
#
# **V. Future Prospects:**
#
# *   **Continued Media Expansion:** The Transformers franchise continues to expand with new films, television shows, and video games planned for the future.
# *   **Innovation and Reinterpretation:** Future iterations are likely to explore new characters, storylines, and visual styles, while staying true to the core themes of the franchise.
# *   **Evolving Fanbase:** The Transformers fanbase continues to grow and evolve, embracing new generations of fans and fostering a vibrant online community.
#
# **Conclusion:**
#
# Transformers is more than just a collection of transforming robot toys; it is a rich and complex universe with compelling characters, engaging storylines, and enduring themes. From its humble beginnings in the 1980s to its current status as a global phenomenon, Transformers has captured the imaginations of audiences worldwide and continues to evolve and adapt for future generations. The enduring popularity of Transformers lies in its ability to blend action, adventure, and philosophical themes into a compelling and entertaining package, proving that these robots in disguise have a lasting impact on popular culture.
