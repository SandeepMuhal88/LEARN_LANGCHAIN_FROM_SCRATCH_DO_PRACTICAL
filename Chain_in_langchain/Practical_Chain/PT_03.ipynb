# %% [markdown]
# Make Parallel Chain in langchain

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
load_dotenv()
# Out:
# d:\Project-to-learn\.langchain\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.11) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# True

# %%
from transformers.models import m2m_100


llms=HuggingFaceEndpoint(
    repo_id="google/gemma-2-2b-it",
    task="text-generation"
)
model=ChatHuggingFace(llm=llms)

# m2=ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash-lite",
#     temperature=0
# )

# %%
temp_01=PromptTemplate(
    template="Explain me summary of that {topic}",
    input_variables=["topic"]
)
temp_02=PromptTemplate(
    template="Explain me this hidden knowledge {text}",
    input_variables=["text"]
)
temp_03=PromptTemplate(
    template="Base on text that is infomation is very systhesis {text_2}",
    input_variables=["text_2"]
)

# %%
parser=StrOutputParser()

# %%
chain=temp_01 | model |parser |temp_02 |model | parser

# %%
result=chain.invoke({'topic':'AI'})
print(result)
# Out:
# You got it!  I'm ready to dive into this hidden AI knowledge.
#
# Please tell me about the AI you're interested in!  😄

# %%
# chain_1=temp_01|m1|parser
# word=chain_1.invoke({'topic':'AI'})
# print(word)
# Out:
# Please provide me with the AI you would like me to summarize! 😊
#
# Tell me:
#
# * **What AI are you interested in?**  Is it a specific model (like GPT-3 or LaMDA), a technology (like machine learning or deep learning), a concept (like AI ethics or bias), or something else?
# * **What kind of summary are you looking for?**  Do you need a brief overview, key points, potential benefits/risks, or something else?
#
# The more information you provide, the better I can understand your request and give you a helpful summary.

# %%
# chain_2=temp_02| m2 | parser
# text_2=chain_2.invoke({'text':'word'})
# print(text_2)
# Out:
# You've presented a fascinating concept! "Hidden knowledge word" is a very evocative phrase, and it can be interpreted in several ways, each pointing to a different kind of "hidden" or "special" word. Let's break down the possibilities:
#
# **1. Words with Hidden Meanings or Connotations:**
#
# *   **Etymology and History:** Many words have a rich history that reveals deeper meanings. For example, the word "disaster" comes from the Greek "dis" (bad) and "aster" (star), implying a misfortune caused by unfavorable celestial alignment. Knowing this etymology adds a layer of hidden meaning.
# *   **Figurative Language:** Words used metaphorically or symbolically carry hidden meanings beyond their literal definitions. "Heart" can represent love, courage, or the core of something.
# ...

# %%
chain=temp_03|m2|parser
result=chain.invoke({'text_2':'text_2'})
print(result)
# Out:
# Please provide me with the text you are referring to. I need the content of "text_2" to be able to synthesize information from it and tell you what it is.
#
# Once you provide the text, I will be able to:
#
# *   **Identify the main topics and themes.**
# *   **Extract key facts and details.**
# *   **Summarize the core arguments or information presented.**
# *   **Highlight any relationships or connections between different pieces of information.**
#
# Looking forward to seeing the text!

# %%
chain.get_graph().print_ascii()
# Out:
#       +-------------+
#       | PromptInput |
#       +-------------+
#              *
#              *
#              *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#              *
#              *
#              *
# +------------------------+
# | ChatGoogleGenerativeAI |
# +------------------------+
#              *
#              *
#              *
#     +-----------------+
#     | StrOutputParser |
#     +-----------------+
#              *
#              *
#              *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
