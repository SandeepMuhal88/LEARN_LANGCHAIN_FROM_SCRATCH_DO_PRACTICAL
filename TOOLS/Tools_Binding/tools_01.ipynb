# %% [markdown]
# create_tool_calling_agent was NOT available in LangChain 1.1.0.
# It was added later (around v0.3.0+ → v1.2.x).
#
# So in 1.1.0, importing this will always fail.

# %%
from langchain_core.tools import Tool

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.1.0

# %%
pip show langchain
