# %% [markdown]
# USE BUilt-in Function to make LLMS

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain.llms import GoogleGenerativeAI
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # from langchain_google_genai import ChatGoogleGenerativeAI
#       2 from langchain_core.prompts import PromptTemplate
# ----> 3 from langchain.llms import GoogleGenerativeAI
#       4 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'langchain.llms'
