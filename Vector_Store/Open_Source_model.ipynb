# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace,HuggingFaceEmbeddings
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install sentence-transformers

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

# %%
# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# 6
doc6 = Document(
    page_content="Hardik Pandya is one of the most explosive all-rounders in the IPL. Known for his power-hitting and quick seam bowling, he has played crucial roles for Mumbai Indians and Gujarat Titans.",
    metadata={"team": "Mumbai Indians / Gujarat Titans"}
)

# 7
doc7 = Document(
    page_content="Shubman Gill is a technically sound opener who excels in timing and placement. Playing for Gujarat Titans, he became one of the top run scorers in recent seasons.",
    metadata={"team": "Gujarat Titans"}
)

# 8
doc8 = Document(
    page_content="Suryakumar Yadav, often called SKY, is known for his 360-degree batting style. Representing Mumbai Indians, he has become one of the most impactful T20 batters.",
    metadata={"team": "Mumbai Indians"}
)

# 9
doc9 = Document(
    page_content="KL Rahul is known for his elegant batting and consistency at the top order. As captain of Lucknow Super Giants, he has delivered multiple high-scoring seasons.",
    metadata={"team": "Lucknow Super Giants"}
)

# 10
doc10 = Document(
    page_content="Rishabh Pant is a fearless wicketkeeper-batsman known for his explosive stroke play. Leading Delhi Capitals, he has been a match-winner with his innovative shots.",
    metadata={"team": "Delhi Capitals"}
)

# 11
doc11 = Document(
    page_content="Andre Russell is one of the most dangerous all-rounders in T20 cricket. Playing for Kolkata Knight Riders, he is famous for his power-hitting and death bowling.",
    metadata={"team": "Kolkata Knight Riders"}
)

# 12
doc12 = Document(
    page_content="Pat Cummins is an elite fast bowler and leader who plays for Sunrisers Hyderabad. Known for his pace, accuracy, and leadership, he delivers under pressure.",
    metadata={"team": "Sunrisers Hyderabad"}
)

# 13
doc13 = Document(
    page_content="David Warner is one of the highest run scorers in IPL history. Known for his aggressive opening style, he has led Sunrisers Hyderabad to an IPL title.",
    metadata={"team": "Sunrisers Hyderabad / Delhi Capitals"}
)

# 14
doc14 = Document(
    page_content="Faf du Plessis is a dependable top-order batsman who leads Royal Challengers Bangalore. Known for his fitness and consistency, he has been a key performer.",
    metadata={"team": "Royal Challengers Bangalore"}
)

# 15
doc15 = Document(
    page_content="Yuzvendra Chahal is one of the most successful leg-spinners in IPL. Playing for Rajasthan Royals, he is known for his wicket-taking ability in the middle overs.",
    metadata={"team": "Rajasthan Royals"}
)

# 16
doc16 = Document(
    page_content="Sanju Samson, captain of Rajasthan Royals, is known for his stylish batting and ability to score big on his day. He is one of the most talented wicketkeeper-batsmen.",
    metadata={"team": "Rajasthan Royals"}
)

# 17
doc17 = Document(
    page_content="Ruturaj Gaikwad is a technically sound opener who represents Chennai Super Kings. Known for his calm temperament, he won the Orange Cap and became a key performer.",
    metadata={"team": "Chennai Super Kings"}
)

# 18
doc18 = Document(
    page_content="Mohammed Shami is a seasoned fast bowler known for his seam movement and accuracy. Playing for Gujarat Titans, he has consistently taken wickets in the powerplay.",
    metadata={"team": "Gujarat Titans"}
)

# 19
doc19 = Document(
    page_content="Rahul Tewatia is a finisher known for his unbelievable comeback innings. Representing Gujarat Titans, he has gained popularity for his clutch hitting under pressure.",
    metadata={"team": "Gujarat Titans"}
)

# 20
doc20 = Document(
    page_content="Sunil Narine is one of the most economical and unpredictable mystery spinners in IPL history. Playing for Kolkata Knight Riders, he also contributes as an explosive opener.",
    metadata={"team": "Kolkata Knight Riders"}
)

# %%
docs=[doc1,doc2,doc3,doc4,doc5,doc6,doc7,doc8,doc9,doc10,doc11,doc12,doc13,doc14,doc15,doc16,doc17,doc18,doc19,doc20]

# %%
vectors_store=Chroma(
    embedding_function=embeddings,
    collection_name="ipl_players_data", 
    persist_directory="vector_store"

)
# Out:
# C:\Users\sande\AppData\Local\Temp\ipykernel_18712\1369878709.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vectors_store=Chroma(

# %%
vectors_store.add_documents(docs)
# Out:
# ['cb7b1cbb-8ef2-46f2-bb5a-fada38a97015',
#  'e9569842-e381-4e6e-a688-eb54374f5627',
#  'c8171c05-2db4-4c74-bc56-658421dfbad3',
#  '2611fd30-096d-4c54-b919-8e31620bf78e',
#  'a22795f0-e9d9-47a4-959f-21774f04f2f0',
#  '182a3145-9fd8-44b7-a118-164ca991f348',
#  '77acb2ae-5f9c-4f99-9846-c7f42714b31c',
#  '6dec7604-3553-49ab-8e38-bb5c079f63e3',
#  'f0ba103b-2850-4f9a-b9a1-e45660efe150',
#  'd217b76b-638d-400e-9d57-29ff1f39cccb',
#  '96d9cafe-a5f9-453d-869f-a28f81a23d77',
#  '24cca883-2df7-4d58-ab46-6d6da46814ae',
#  'c103633d-cdea-4ec6-b98d-73811bd9a66e',
#  '1acc3b10-c042-4bf7-b240-eb71040afc2e',
#  'e8c0aa09-08ee-45e6-a0aa-a63e96ec3721',
#  '6a4029cd-4d5d-420f-92c0-780c5053f1bb',
#  'b600d1b7-a9c7-4ea3-a3d0-f0bc3f52a3b7',
#  'f890d0e8-f852-439a-94ae-5bcf28e7adb0',
#  '53ebe27e-2f97-4845-835a-9a4e85271031',
#  '90270e48-e991-4640-8778-c247f860a0bb']

# %%
# view documents
vectors_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['cb7b1cbb-8ef2-46f2-bb5a-fada38a97015',
#   'e9569842-e381-4e6e-a688-eb54374f5627',
#   'c8171c05-2db4-4c74-bc56-658421dfbad3',
#   '2611fd30-096d-4c54-b919-8e31620bf78e',
#   'a22795f0-e9d9-47a4-959f-21774f04f2f0',
#   '182a3145-9fd8-44b7-a118-164ca991f348',
#   '77acb2ae-5f9c-4f99-9846-c7f42714b31c',
#   '6dec7604-3553-49ab-8e38-bb5c079f63e3',
#   'f0ba103b-2850-4f9a-b9a1-e45660efe150',
#   'd217b76b-638d-400e-9d57-29ff1f39cccb',
#   '96d9cafe-a5f9-453d-869f-a28f81a23d77',
#   '24cca883-2df7-4d58-ab46-6d6da46814ae',
#   'c103633d-cdea-4ec6-b98d-73811bd9a66e',
#   '1acc3b10-c042-4bf7-b240-eb71040afc2e',
#   'e8c0aa09-08ee-45e6-a0aa-a63e96ec3721',
#   '6a4029cd-4d5d-420f-92c0-780c5053f1bb',
#   'b600d1b7-a9c7-4ea3-a3d0-f0bc3f52a3b7',
#   'f890d0e8-f852-439a-94ae-5bcf28e7adb0',
#   '53ebe27e-2f97-4845-835a-9a4e85271031',
#   '90270e48-e991-4640-8778-c247f860a0bb'],
#  'embeddings': array([[ 0.00994723,  0.06914332, -0.05147117, ..., -0.03543343,
# ...

# %%
# Search Document
vectors_store.similarity_search(
    "What is the best IPL team?",
    k=2
    )
# Out:
# [Document(metadata={'team': 'Sunrisers Hyderabad / Delhi Capitals'}, page_content='David Warner is one of the highest run scorers in IPL history. Known for his aggressive opening style, he has led Sunrisers Hyderabad to an IPL title.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
vectors_store.similarity_search(
    "What is the bestman in IPL?",
    k=5
    )
# Out:
# [Document(metadata={'team': 'Sunrisers Hyderabad / Delhi Capitals'}, page_content='David Warner is one of the highest run scorers in IPL history. Known for his aggressive opening style, he has led Sunrisers Hyderabad to an IPL title.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#  Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#  Document(metadata={'team': 'Mumbai Indians / Gujarat Titans'}, page_content='Hardik Pandya is one of the most explosive all-rounders in the IPL. Known for his power-hitting and quick seam bowling, he has played crucial roles for Mumbai Indians and Gujarat Titans.'),
# ...

# %%
vectors_store.similarity_search(
    "Who is best bowler in IPL?",
    k=1
    )
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
# Metadata flittering
vectors_store.similarity_search_with_score(
    query="What is the best IPL team?",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.0864942073822021),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.548498272895813),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ruturaj Gaikwad is a technically sound opener who represents Chennai Super Kings. Known for his calm temperament, he won the Orange Cap and became a key performer.'),
#   1.709090232849121)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vectors_store.update_document(document_id='cb7b1cbb-8ef2-46f2-bb5a-fada38a97015', document=updated_doc1)

# %%
vectors_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['cb7b1cbb-8ef2-46f2-bb5a-fada38a97015',
#   'e9569842-e381-4e6e-a688-eb54374f5627',
#   'c8171c05-2db4-4c74-bc56-658421dfbad3',
#   '2611fd30-096d-4c54-b919-8e31620bf78e',
#   'a22795f0-e9d9-47a4-959f-21774f04f2f0',
#   '182a3145-9fd8-44b7-a118-164ca991f348',
#   '77acb2ae-5f9c-4f99-9846-c7f42714b31c',
#   '6dec7604-3553-49ab-8e38-bb5c079f63e3',
#   'f0ba103b-2850-4f9a-b9a1-e45660efe150',
#   'd217b76b-638d-400e-9d57-29ff1f39cccb',
#   '96d9cafe-a5f9-453d-869f-a28f81a23d77',
#   '24cca883-2df7-4d58-ab46-6d6da46814ae',
#   'c103633d-cdea-4ec6-b98d-73811bd9a66e',
#   '1acc3b10-c042-4bf7-b240-eb71040afc2e',
#   'e8c0aa09-08ee-45e6-a0aa-a63e96ec3721',
#   '6a4029cd-4d5d-420f-92c0-780c5053f1bb',
#   'b600d1b7-a9c7-4ea3-a3d0-f0bc3f52a3b7',
#   'f890d0e8-f852-439a-94ae-5bcf28e7adb0',
#   '53ebe27e-2f97-4845-835a-9a4e85271031',
#   '90270e48-e991-4640-8778-c247f860a0bb'],
#  'embeddings': array([[-0.00233748,  0.05902078, -0.04774045, ..., -0.07264049,
# ...

# %%
vectors_store.delete(ids=['cb7b1cbb-8ef2-46f2-bb5a-fada38a97015'])

# %%
vectors_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['e9569842-e381-4e6e-a688-eb54374f5627',
#   'c8171c05-2db4-4c74-bc56-658421dfbad3',
#   '2611fd30-096d-4c54-b919-8e31620bf78e',
#   'a22795f0-e9d9-47a4-959f-21774f04f2f0',
#   '182a3145-9fd8-44b7-a118-164ca991f348',
#   '77acb2ae-5f9c-4f99-9846-c7f42714b31c',
#   '6dec7604-3553-49ab-8e38-bb5c079f63e3',
#   'f0ba103b-2850-4f9a-b9a1-e45660efe150',
#   'd217b76b-638d-400e-9d57-29ff1f39cccb',
#   '96d9cafe-a5f9-453d-869f-a28f81a23d77',
#   '24cca883-2df7-4d58-ab46-6d6da46814ae',
#   'c103633d-cdea-4ec6-b98d-73811bd9a66e',
#   '1acc3b10-c042-4bf7-b240-eb71040afc2e',
#   'e8c0aa09-08ee-45e6-a0aa-a63e96ec3721',
#   '6a4029cd-4d5d-420f-92c0-780c5053f1bb',
#   'b600d1b7-a9c7-4ea3-a3d0-f0bc3f52a3b7',
#   'f890d0e8-f852-439a-94ae-5bcf28e7adb0',
#   '53ebe27e-2f97-4845-835a-9a4e85271031',
#   '90270e48-e991-4640-8778-c247f860a0bb'],
#  'embeddings': array([[ 0.00127751,  0.03129848, -0.02375381, ..., -0.00518363,
#          -0.03280612,  0.02737715],
# ...
