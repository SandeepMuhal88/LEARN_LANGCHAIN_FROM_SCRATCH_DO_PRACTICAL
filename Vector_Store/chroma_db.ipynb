# %%
from langchain_community.vectorstores import Chroma


from langchain_huggingface import HuggingFaceEmbeddings
embedding=HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.documents import Document

# %%
# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs=[doc1,doc2,doc3,doc4,doc5]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embedding=HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
# %pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-1.3.5-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (2.12.5)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Using cached pybase64-1.4.2-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.22.5 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (2.3.5)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.23.2-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.2.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in d:\project-to-learn\.langchain\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in d:\project-to-learn\.langchain\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\project-to-learn\.langchain\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\project-to-learn\.langchain\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in d:\project-to-learn\.langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in d:\project-to-learn\.langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.1)
# Requirement already satisfied: sympy in d:\project-to-learn\.langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: zipp>=3.20 in d:\project-to-learn\.langchain\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\project-to-learn\.langchain\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\project-to-learn\.langchain\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\project-to-learn\.langchain\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in d:\project-to-learn\.langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\project-to-learn\.langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\project-to-learn\.langchain\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.7.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\project-to-learn\.langchain\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.1.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in d:\project-to-learn\.langchain\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyreadline3 in d:\project-to-learn\.langchain\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\project-to-learn\.langchain\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached chromadb-1.3.5-cp39-abi3-win_amd64.whl (21.7 MB)
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Using cached build-1.3.0-py3-none-any.whl (23 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.2.0-cp311-cp311-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.23.2-cp311-cp311-win_amd64.whl (13.5 MB)
# Using cached opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Using cached pybase64-1.4.2-cp311-cp311-win_amd64.whl (35 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached httptools-0.7.1-cp311-cp311-win_amd64.whl (86 kB)
# Using cached watchfiles-1.1.1-cp311-cp311-win_amd64.whl (287 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyproject_hooks, pybase64, opentelemetry-proto, mmh3, mdurl, importlib-resources, importlib-metadata, humanfriendly, httptools, distro, bcrypt, backoff, watchfiles, uvicorn, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, coloredlogs, build, rich, opentelemetry-semantic-conventions, onnxruntime, kubernetes, typer, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    - --------------------------------------  1/28 [pybase64]
#    ----- ----------------------------------  4/28 [mdurl]
#    -------- -------------------------------  6/28 [importlib-metadata]
#    ---------- -----------------------------  7/28 [humanfriendly]
#    ---------- -----------------------------  7/28 [humanfriendly]
#    ---------- -----------------------------  7/28 [humanfriendly]
#    ------------ ---------------------------  9/28 [distro]
#    --------------- ------------------------ 11/28 [backoff]
#    ------------------ --------------------- 13/28 [uvicorn]
#    ------------------ --------------------- 13/28 [uvicorn]
#    ------------------ --------------------- 13/28 [uvicorn]
#    -------------------- ------------------- 14/28 [posthog]
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\Project-to-learn\\.langchain\\Lib\\site-packages\\posthog\\ai\\openai\\openai_providers.py'
# Check the permissions.
# Collecting chromadb
#   Using cached chromadb-1.3.5-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pydantic>=1.9 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (2.12.5)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.22.5 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (2.3.5)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.2-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (0.22.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (6.0.3)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\project-to-learn\.langchain\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\project-to-learn\.langchain\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\project-to-learn\.langchain\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in d:\project-to-learn\.langchain\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in d:\project-to-learn\.langchain\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in d:\project-to-learn\.langchain\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\project-to-learn\.langchain\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\project-to-learn\.langchain\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in d:\project-to-learn\.langchain\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\project-to-learn\.langchain\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\project-to-learn\.langchain\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in d:\project-to-learn\.langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.1)
# Requirement already satisfied: sympy in d:\project-to-learn\.langchain\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\project-to-learn\.langchain\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\project-to-learn\.langchain\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\project-to-learn\.langchain\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\project-to-learn\.langchain\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in d:\project-to-learn\.langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\project-to-learn\.langchain\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\project-to-learn\.langchain\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\project-to-learn\.langchain\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\project-to-learn\.langchain\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached chromadb-1.3.5-cp39-abi3-win_amd64.whl (21.7 MB)
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Using cached build-1.3.0-py3-none-any.whl (23 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp311-cp311-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.23.2-cp311-cp311-win_amd64.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.5 MB 2.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/13.5 MB 2.7 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/13.5 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 3.1/13.5 MB 3.4 MB/s eta 0:00:04
#    ------------ --------------------------- 4.2/13.5 MB 3.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.5/13.5 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 7.3/13.5 MB 4.7 MB/s eta 0:00:02
#    -------------------------- ------------- 8.9/13.5 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 11.0/13.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 6.2 MB/s  0:00:02
# Using cached opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading pybase64-1.4.2-cp311-cp311-win_amd64.whl (35 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading httptools-0.7.1-cp311-cp311-win_amd64.whl (86 kB)
# Downloading watchfiles-1.1.1-cp311-cp311-win_amd64.whl (287 kB)
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=2b72c5d431ded6531a2155a3ce5a9511461c19515600bd798ce00138316b5336
#   Stored in directory: c:\users\sande\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, urllib3, shellingham, pyreadline3, pyproject_hooks, pybase64, opentelemetry-proto, mmh3, mdurl, importlib-resources, httptools, distro, bcrypt, backoff, watchfiles, uvicorn, opentelemetry-exporter-otlp-proto-common, markdown-it-py, importlib-metadata, humanfriendly, build, rich, posthog, opentelemetry-api, coloredlogs, typer, opentelemetry-semantic-conventions, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    - --------------------------------------  1/36 [flatbuffers]
#    - --------------------------------------  1/36 [flatbuffers]
#    --- ------------------------------------  3/36 [zipp]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#    ---- -----------------------------------  4/36 [websockets]
#   Attempting uninstall: urllib3
#    ---- -----------------------------------  4/36 [websockets]
#     Found existing installation: urllib3 2.5.0
#    ---- -----------------------------------  4/36 [websockets]
#     Uninstalling urllib3-2.5.0:
#    ---- -----------------------------------  4/36 [websockets]
#       Successfully uninstalled urllib3-2.5.0
#    ---- -----------------------------------  4/36 [websockets]
#    ----- ----------------------------------  5/36 [urllib3]
#    ----- ----------------------------------  5/36 [urllib3]
#    ----- ----------------------------------  5/36 [urllib3]
#    ----- ----------------------------------  5/36 [urllib3]
#    ----- ----------------------------------  5/36 [urllib3]
#    ------ ---------------------------------  6/36 [shellingham]
#    ------- --------------------------------  7/36 [pyreadline3]
#    ------- --------------------------------  7/36 [pyreadline3]
#    ------- --------------------------------  7/36 [pyreadline3]
#    ------- --------------------------------  7/36 [pyreadline3]
#    ------- --------------------------------  7/36 [pyreadline3]
#    ---------- -----------------------------  9/36 [pybase64]
#    ---------- -----------------------------  9/36 [pybase64]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ----------- ---------------------------- 10/36 [opentelemetry-proto]
#    ------------- -------------------------- 12/36 [mdurl]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    -------------- ------------------------- 13/36 [importlib-resources]
#    ---------------- ----------------------- 15/36 [distro]
#    ---------------- ----------------------- 15/36 [distro]
#    ------------------ --------------------- 17/36 [backoff]
#    -------------------- ------------------- 18/36 [watchfiles]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------------- ------------------ 19/36 [uvicorn]
#    --------------- ----------- 20/36 [opentelemetry-exporter-otlp-proto-common]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ----------------------- ---------------- 21/36 [markdown-it-py]
#    ------------------------ --------------- 22/36 [importlib-metadata]
#    ------------------------- -------------- 23/36 [humanfriendly]
#    ------------------------- -------------- 23/36 [humanfriendly]
#    ------------------------- -------------- 23/36 [humanfriendly]
#    ------------------------- -------------- 23/36 [humanfriendly]
#    -------------------------- ------------- 24/36 [build]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    --------------------------- ------------ 25/36 [rich]
#    ---------------------------- ----------- 26/36 [posthog]
#    ---------------------------- ----------- 26/36 [posthog]
#    ---------------------------- ----------- 26/36 [posthog]
#    ---------------------------- ----------- 26/36 [posthog]
#    ---------------------------- ----------- 26/36 [posthog]
#    ---------------------------- ----------- 26/36 [posthog]
#    ------------------------------ --------- 27/36 [opentelemetry-api]
#    ------------------------------ --------- 27/36 [opentelemetry-api]
#    ------------------------------ --------- 27/36 [opentelemetry-api]
#    ------------------------------ --------- 27/36 [opentelemetry-api]
#    ------------------------------- -------- 28/36 [coloredlogs]
#    -------------------------------- ------- 29/36 [typer]
#    -------------------------------- ------- 29/36 [typer]
#    -------------------------------- ------- 29/36 [typer]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 30/36 [opentelemetry-semantic-conventions]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ---------------------------------- ----- 31/36 [onnxruntime]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ----------------------------------- ---- 32/36 [kubernetes]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    ------------------------------------ --- 33/36 [opentelemetry-sdk]
#    --------------------------- - 34/36 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    -------------------------------------- - 35/36 [chromadb]
#    ---------------------------------------- 36/36 [chromadb]
#
# Successfully installed backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 chromadb-1.3.5 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.9.23 httptools-0.7.1 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-34.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 onnxruntime-1.23.2 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 rich-14.2.0 shellingham-1.5.4 typer-0.20.0 urllib3-2.3.0 uvicorn-0.38.0 watchfiles-1.1.1 websockets-15.0.1 zipp-3.23.0

# %%
vector_store=Chroma(
    embedding_function=embedding,
    collection_name="ipl_players",
    persist_directory="chDB"
)

# %%
vector_store.add_documents(docs)
# Out:
# ['aa489698-6b0a-4de8-a121-0f7780a08548',
#  'd8c127f3-47d3-44cd-90b5-d3c7858f5e24',
#  '004c3d23-7a9c-4cd0-86c8-3cdb7fc5f2e1',
#  '12b1f770-5599-474a-ad11-f31246e3cd87',
#  'f209b3c0-bc70-4263-86e7-973bd1ea90a9']

# %%
#that error not from  langchain its from google embedding that recently shutdown there free model
